# %%
# %matplotlib inline
import numpy as np
import lazyplot

# %%
x1 = np.random.rand(30)
x2 = np.random.rand(2, 30)

fig = lazyplot.lazy_plot(x2)
fig.show()
# Out:
# c:\Users\hiroh\work\lazyplot\lazyplot\plot.py:106: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\hiroh\AppData\Local\Temp\ipykernel_2904\3656591735.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
