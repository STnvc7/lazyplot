# %%
import numpy as np
import lazyplot
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
x1 = np.random.rand(200)
x2 = np.random.rand(4, 30)
lazyplot.lazy_plot(x2, out_path=None, user_config={"plot_type_2d": "plot"})
